# %% [markdown]
# # Global Cyberattack Pattern Analysis — Data Mining (Anaconda Edition)
#
# **Notebook:** 04_supervised_classification.ipynb
# Train RandomForest & LinearSVC and export metrics + confusion matrices.

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import joblib
import os

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
import matplotlib.pyplot as plt

# Detect project root 
ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent

METRICS_DIR = ROOT / "reports" / "metrics"
SUP_DIR     = ROOT / "reports" / "supervised"
SUP_DIR.mkdir(parents=True, exist_ok=True)

# Load splits & metadata created in 03_preprocess_feature_engineering

splits = joblib.load(METRICS_DIR / "splits.joblib")
meta   = joblib.load(METRICS_DIR / "feature_meta.joblib")

X_train, X_test = splits["X_train"], splits["X_test"]
y_train, y_test = splits["y_train"], splits["y_test"]
feature_cols    = meta["feature_cols"]
cat_cols        = meta["cat_cols"]
num_cols        = meta["num_cols"]
target_name     = meta["target_name"]

X_train.head(), y_train.head()
# Out:
# (    vendorProject                                            product  \
#  709         Adobe                               Flash Player and AIR
#  342         Cisco  Adaptive Security Appliance (ASA) and Firepowe...
#  66            PHP                                          PHPMailer
#  538       Synacor                   Zimbra Collaboration Suite (ZCS)
#  491         Zyxel    Multiple Network-Attached Storage (NAS) Devices
#
#      cwe_primary  year_added  month_added  ransomware_known
#  709     CWE-416        2022            5             False
#  342     CWE-835        2024            4             False
#  66       CWE-77        2025            7             False
#  538      CWE-79        2023            4             False
#  491      CWE-78        2023            6             False  ,
#  709    Fast
#  342    Fast
#  66     Fast
#  538    Fast
#  491    Fast
#  Name: response_speed, dtype: category
#  Categories (3, object): ['Fast' < 'Medium' < 'Slow'])

# %%
# Rebuild the preprocessing pipeline exactly as in 03 (impute + one-hot)

from sklearn.pipeline import Pipeline

preprocess = ColumnTransformer([
    ("cat", Pipeline([
        ("imp", SimpleImputer(strategy="most_frequent")),
        ("oh",  OneHotEncoder(handle_unknown="ignore"))
    ]), cat_cols),
    ("num", Pipeline([
        ("imp", SimpleImputer(strategy="median"))
    ]), num_cols)
])

# Fit the preprocessor on training data only
preprocess.fit(X_train)
# Out:
# ColumnTransformer(transformers=[('cat',
#                                  Pipeline(steps=[('imp',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('oh',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  ['vendorProject', 'product', 'cwe_primary']),
#                                 ('num',
#                                  Pipeline(steps=[('imp',
#                                                   SimpleImputer(strategy='median'))]),
#                                  ['year_added', 'month_added',
#                                   'ransomware_known'])])

# %%
# EN: Train RandomForest. class_weight="balanced" helps with imbalanced classes.

rf = Pipeline([
    ("prep", preprocess),
    ("clf", RandomForestClassifier(
        n_estimators=400, random_state=42, class_weight="balanced"
    ))
])

rf.fit(X_train, y_train)
rf_pred = rf.predict(X_test)

# Metrics

rf_report = classification_report(y_test, rf_pred, output_dict=True)
pd.DataFrame(rf_report).to_csv(METRICS_DIR / f"classification_report_rf_{target_name}.csv")
print(pd.DataFrame(rf_report))

# Confusion Matrix

labels = sorted(y_train.unique().tolist())
cm = confusion_matrix(y_test, rf_pred, labels=labels)
disp = ConfusionMatrixDisplay(cm, display_labels=labels)
disp.plot(values_format="d")
plt.title(f"RandomForest — Confusion Matrix ({target_name})")
plt.tight_layout()
plt.savefig(SUP_DIR / f"confusion_matrix_rf_{target_name}.png", dpi=200)

# Save model

joblib.dump(rf, SUP_DIR / f"model_random_forest_{target_name}.joblib")
print("✅ Saved RF model & metrics to:", SUP_DIR, METRICS_DIR)
# Out:
#                  Fast  Medium       Slow  accuracy   macro avg  weighted avg
# precision    0.948718     1.0   0.725490  0.909091    0.891403      0.910652
# recall       0.940678     1.0   0.755102  0.909091    0.898593      0.909091
# f1-score     0.944681     1.0   0.740000  0.909091    0.894894      0.909807
# support    236.000000     1.0  49.000000  0.909091  286.000000    286.000000
# ✅ Saved RF model & metrics to: C:\Users\asus\Downloads\global_cyberattack_dm_anaconda\global_cyberattack_dm\reports\supervised C:\Users\asus\Downloads\global_cyberattack_dm_anaconda\global_cyberattack_dm\reports\metrics

# %%
# Train LinearSVC as a linear baseline. Good for high-dimensional one-hot features.

svm = Pipeline([
    ("prep", preprocess),
    ("clf", LinearSVC(random_state=42))
])

svm.fit(X_train, y_train)
svm_pred = svm.predict(X_test)

# Metrics

svm_report = classification_report(y_test, svm_pred, output_dict=True)
pd.DataFrame(svm_report).to_csv(METRICS_DIR / f"classification_report_svm_{target_name}.csv")
print(pd.DataFrame(svm_report))

# Confusion Matrix

cm2 = confusion_matrix(y_test, svm_pred, labels=labels)
disp2 = ConfusionMatrixDisplay(cm2, display_labels=labels)
disp2.plot(values_format="d")
plt.title(f"LinearSVC — Confusion Matrix ({target_name})")
plt.tight_layout()
plt.savefig(SUP_DIR / f"confusion_matrix_svm_{target_name}.png", dpi=200)

# Save model

joblib.dump(svm, SUP_DIR / f"model_linearsvc_{target_name}.joblib")
print("✅ Saved SVM model & metrics to:", SUP_DIR, METRICS_DIR)
# Out:
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\asus\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
# Create a compact metrics table (Accuracy, Macro-Precision/Recall/F1) for both models.

def shrink(report):
    df = pd.DataFrame(report).T
    row = df.loc[["accuracy"]].rename(index={"accuracy": "Accuracy"})
    macro = df.loc["macro avg", ["precision","recall","f1-score"]].rename({
        "precision":"Precision(macro)",
        "recall":"Recall(macro)",
        "f1-score":"F1(macro)"
    })
    return pd.concat([row, macro])

cmp = pd.concat([
    shrink(rf_report).rename(columns=lambda c: f"RF_{c}"),
    shrink(svm_report).rename(columns=lambda c: f"SVM_{c}")
], axis=1)

cmp.to_csv(METRICS_DIR / f"model_comparison_{target_name}.csv")
cmp
# Out:
#                   RF_precision  RF_recall  RF_f1-score  RF_support  \
# Accuracy              0.909091   0.909091     0.909091    0.909091
# Precision(macro)           NaN        NaN          NaN         NaN
# Recall(macro)              NaN        NaN          NaN         NaN
# F1(macro)                  NaN        NaN          NaN         NaN
#
#                   RF_macro avg  SVM_precision  SVM_recall  SVM_f1-score  \
# Accuracy                   NaN        0.84965     0.84965       0.84965
# Precision(macro)      0.891403            NaN         NaN           NaN
# Recall(macro)         0.898593            NaN         NaN           NaN
# F1(macro)             0.894894            NaN         NaN           NaN
#
#                   SVM_support  SVM_macro avg
# Accuracy              0.84965            NaN
# Precision(macro)          NaN       0.503244
# Recall(macro)             NaN       0.429465
# F1(macro)                 NaN       0.448638
